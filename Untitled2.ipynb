# %% [markdown]
# <a href="https://colab.research.google.com/github/nikitha23-niki/DS-Project-/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
response = requests.get(url, timeout=10)
issues = response.json()
df_issues = pd.DataFrame(issues)
print(df_issues[["id", "title", "state", "created_at"]].head())
# Out:
#            id                                              title state  \
# 0  5147436559  BUG: read_parquet raised for nested pyarrow dt...  open
# 1  5147159849  Fix #61692: ENH: Add `excel_sep_hint` paramete...  open
# 2  5147023967  PERF: single-pass string conversion in read_cs...  open
# 3  5146290117   BUG: cast values before categorical dtype lookup  open
# 4  5145860798  BUG: ewm(adjust=False) NaN gaps disagree for t...  open
#
#              created_at
# 0  2026-08-14T01:54:41Z
# 1  2026-08-14T01:00:14Z
# 2  2026-08-14T00:34:15Z
# 3  2026-08-13T22:14:30Z
# 4  2026-08-13T21:09:36Z
