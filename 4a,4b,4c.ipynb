# %% [markdown]
# <a href="https://colab.research.google.com/github/nikitha23-niki/DS-Project-/blob/main/4a%2C4b%2C4c.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
index = [
    ['Engineering','Engineering','Science','Science'],
    ['CSE','ECE','Physic','Chmistry']
    ]
multi_index = pd.MultiIndex.from_arrays(
    index,
    names=['Department', 'Branch']
)
marks = pd.Series(
    [85,78,92,88],
    index = multi_index
)
print("Original Series:")
print(marks)
print("\nData for Engineering:")
print(marks.loc['Engineering'])
print("\nData for CSE:")
print(marks.loc[('Engineering','CSE')])
print("\nData for Science:")
print(marks.loc['Science'])
# Out:
# Original Series:
# Department   Branch
# Engineering  CSE         85
#              ECE         78
# Science      Physic      92
#              Chmistry    88
# dtype: int64
#
# Data for Engineering:
# Branch
# CSE    85
# ECE    78
# dtype: int64
#
# Data for CSE:
# 85
#
# Data for Science:
# Branch
# Physic      92
# Chmistry    88
# dtype: int64

# %%
import pandas as pd
index = pd.MultiIndex.from_tuples(
    [
        ('Engineering','CSE'),
        ('Engineering','ECE'),
        ('Science','Physics'),
        ('Science','Chemistry')
    ],
    names = ['Department','Branch']
)
data = pd.DataFrame(
    {
        '2025': [85,78,92,88],
        '2026': [90,82,95,91]
    },
    index = index
)
print("Original Tabular Data:")
print(data)
unstacked_data = data.unstack()
print("\nData after Unstack():")
print(unstacked_data)
stacked_data = unstacked_data.stack()
print("\nData after Stack():")
print(stacked_data)
# Out:
# Original Tabular Data:
#                        2025  2026
# Department  Branch
# Engineering CSE          85    90
#             ECE          78    82
# Science     Physics      92    95
#             Chemistry    88    91
#
# Data after Unstack():
#              2025                          2026
# Branch        CSE Chemistry   ECE Physics   CSE Chemistry   ECE Physics
# Department
# Engineering  85.0       NaN  78.0     NaN  90.0       NaN  82.0     NaN
# Science       NaN      88.0   NaN    92.0   NaN      91.0   NaN    95.0
#
# Data after Stack():
#                        2025  2026
# Department  Branch
# Engineering CSE        85.0  90.0
#             ECE        78.0  82.0
# Science     Chemistry  88.0  91.0
#             Physics    92.0  95.0
# /tmp/ipykernel_3666/902769684.py:23: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   stacked_data = unstacked_data.stack()

# %%
import pandas as pd
df1 = pd.DataFrame(
    {
        'Name': ['Niki', 'Varshi', 'Chaitu'],
        'Marks': [85, None, 78],
        'Grade': ['A', 'B', None]
    },
    index=[101, 102, 103]
)
df2 = pd.DataFrame(
    {
        'Name': ['Niki', 'Varshi', 'Reddy'],
        'Marks': [90, 88, 82],
        'Grade': [None, 'A', 'B']
    },
    index=[101, 102, 104]
)
print("First DataFrame:")
print(df1)
print("\nSecond DataFrame:")
print(df2)
merged = pd.merge(
    df1,
    df2,
    left_index=True,
    right_index=True,
    how='outer',
    suffixes=('_DF1', '_DF2')
)
print("\nMerged DataFrame:")
print(merged)
combined = df1.combine_first(df2)
print("\nDataFrame after combine_first():")
print(combined)
# Out:
# First DataFrame:
#        Name  Marks Grade
# 101    Niki   85.0     A
# 102  Varshi    NaN     B
# 103  Chaitu   78.0  None
#
# Second DataFrame:
#        Name  Marks Grade
# 101    Niki     90  None
# 102  Varshi     88     A
# 104   Reddy     82     B
#
# Merged DataFrame:
#     Name_DF1  Marks_DF1 Grade_DF1 Name_DF2  Marks_DF2 Grade_DF2
# 101     Niki       85.0         A     Niki       90.0      None
# 102   Varshi        NaN         B   Varshi       88.0         A
# 103   Chaitu       78.0      None      NaN        NaN       NaN
# 104      NaN        NaN       NaN    Reddy       82.0         B
#
# DataFrame after combine_first():
#        Name  Marks Grade
# 101    Niki   85.0     A
# 102  Varshi   88.0     B
# 103  Chaitu   78.0   NaN
# 104   Reddy   82.0     B
